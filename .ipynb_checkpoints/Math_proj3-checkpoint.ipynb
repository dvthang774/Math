# %%
# thư viện
import numpy as np
import pandas as pd
import THANG as ta
# %reload_ext autoreload
# %autoreload 2

# %%
data = pd.read_csv('data.csv')
data
# Out:
#      Screen Size     Weight  Brightness
# 0      10.006692  29.313384   19.825988
# 1      10.081624  29.463248   19.993238
# 2      10.072873  29.445746   19.973641
# 3       9.954496  29.208992   19.710221
# 4       9.994093  29.288185   19.797988
# ..           ...        ...         ...
# 995    10.034021  29.368042   19.886842
# 996    10.068130  29.436260   19.963027
# 997     9.969032  29.238063   19.742399
# 998     9.939579  29.179159   19.677249
# 999     9.865479  29.030957   19.514185
#
# [1000 rows x 3 columns]

# %%
d1=data["Screen Size"]
d2= data["Weight"]
d3= data["Brightness"]

# %%
proj_1=ta.proj2(d1)
# proj_1.standardize()
proj_1.hist()
proj_1.qq()
proj_1.shapiro()
proj_1.kstest()
# Out:
# --------------------------------------------------
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# --------------------------------------------------
#       Screen Size
# 0.25    -0.703580
# 0.50     0.033880
# 0.75     0.650829
# --------------------------------------------------
# kiểm định shapiro:
# stat-0.999, p-0.732
# Không thể bác bỏ H0: Phân phối dữ liệu là chuẩn
# --------------------------------------------------
# kiểm định kstest:
# stat-0.025, p-0.551
# Đấy không phải dữ liệu phân phối chuẩn
# --------------------------------------------------

# %%
proj_2=ta.proj2(d2)
proj_2.hist()
proj_2.qq()
proj_2.shapiro()
proj_2.kstest()
# Out:
# --------------------------------------------------
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# --------------------------------------------------
#              0
# 0.25 -0.703580
# 0.50  0.033880
# 0.75  0.650829
# --------------------------------------------------
# --------------------------------------------------
# kiểm định shapiro:
# stat-0.999, p-0.732
# Không thể bác bỏ H0: Phân phối dữ liệu là chuẩn
# --------------------------------------------------
# kiểm định kstest:
# stat-0.025, p-0.551
# Đấy không phải dữ liệu phân phối chuẩn
# --------------------------------------------------

# %%
proj_3=ta.proj2(d3)
proj_3.hist()
proj_3.qq()
proj_3.quantile([0.25,0.5,0.75])
proj_3.shapiro()
proj_3.kstest()
# Out:
# --------------------------------------------------
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# --------------------------------------------------
#       Brightness
# 0.25   -0.704766
# 0.50    0.031442
# 0.75    0.649380
# --------------------------------------------------
# --------------------------------------------------
# kiểm định shapiro:
# stat-0.999, p-0.698
# Không thể bác bỏ H0: Phân phối dữ liệu là chuẩn
# --------------------------------------------------
# kiểm định kstest:
# stat-0.024, p-0.591
# Đấy không phải dữ liệu phân phối chuẩn
# --------------------------------------------------

# %%
#kiểm định thuần nhất:
ta.levene(d1,d2,d3)
ta.bartlett(d1,d2,d3)
# Out:
#  Levene's Test:
# statistic by Levene  =  232.0294368715241
# pvalue by Levene =  2.0437017282021978e-94
# các Features không có tính thuần nhất
# --------------------------------------------------
#  Bartlett’s Test:
# statistic by Bartlett =  609.1564291909631
# pvalue by Bartlett =  5.288860269864926e-133
# Không đủ bằng chứng để bác bỏ: Đây là các dữ liệu đồng nhất
# --------------------------------------------------
